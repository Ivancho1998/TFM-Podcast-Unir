# %%
pip install pymongo

# %%
from pymongo import MongoClient # Importing the MongoClient class from pymongo

# %%
# Reemplaza el siguiente string con tu conexión URI de MongoDB Atlas
#uri = "mongodb+srv://jackelinelopezceron:podcast1234@clpodcast.xcjjt.mongodb.net/?retryWrites=true&w=majority&appName=Clpodcast"
uri = "mongodb+srv://tfm:tfm123@cluster0.ce7no.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Conectar al cliente de MongoDB
client3 = MongoClient(uri)

# Selecciona la base de datos
db2 = client3['TFM']

# Prueba la conexión
try:
    client3.server_info()  # Esto lanzará una excepción si no se puede conectar
    print("Conexión exitosa a MongoDB Atlas!")
except Exception as e:
    print("Error al conectar a MongoDB Atlas:", e)
# Out:
# Conexión exitosa a MongoDB Atlas!

# %%
collection2 = db2['Descripciones_trabajados']

# %%
# Obtener un documento de la colección
document = collection2.find_one()

# Imprimir el documento
if document:
    print(document)
else:
    print("No se encontraron documentos en la colección.")
# Out:
# {'_id': ObjectId('6774708126b6f2028721a90e'), 'video_id': 'jWhhuVzoMDw', 'description': '⚠️ ADVERTENCIA ⚠️ Este episodio es extremadamente HONESTO en cómo se llevaría una conversación REAL fuera de cámaras, por lo que algunos momentos quizás pueden ser no tan políticamente correctos pero buscan ser lo más sinceros posibles. \n\n🚨 ¿QUIERES PARTICIPAR PARA GANARTE USD $5,000 PARA VIAJAR DESDE CUALQUIER PARTE DE LATINOAMÉRICA? ¡Checa aquí los requisitos que son FACILÍSIMOS!  https://www.instagram.com/p/C4yLEaRrv0f/?igsh=OWJ5ejJ3bzdkbmV5\n\nhttps://www.instagram.com/p/C4yLEaRrv0f/?igsh=OWJ5ejJ3bzdkbmV5\nhttps://www.instagram.com/p/C4yLEaRrv0f/?igsh=OWJ5ejJ3bzdkbmV5\n\n¡Hazte miembro del canal para que cada vez pueda hacer más y mejor contenido! \nhttps://www.youtube.com/channel/UCj8tGGQAQTGoKjTLpYSu8RA/join\n\n¡ESCÚCHANOS EN SPOTIFY!\nhttps://open.spotify.com/show/0txDP7V0My1AcqI8qBQyzn?si=26FkGHXHTeSErHdt9f8aog&nd=1\n\nApple Music\nhttps://podcasts.apple.com/gt/podcast/pic-pod-podcast-c
# ...

# %%
import pandas as pd

# Obtener todos los documentos de la colección
documents = list(collection2.find({}))

# Crear un DataFrame de pandas
df = pd.DataFrame(documents)

# Imprimir el DataFrame
df
# Out:
#                            _id     video_id  \
# 0     6774708126b6f2028721a90e  jWhhuVzoMDw
# 1     6774708126b6f2028721a90f  mqLBdNUkt1U
# 2     6774708126b6f2028721a910  4BE0BwJdVUc
# 3     6774708126b6f2028721a911  Ev0e5Jh4JR4
# 4     6774708126b6f2028721a912  HRv7b8j88Ks
# ...                        ...          ...
# 3449  6775c30a26b6f2028721b689  84wDTy0JTk4
# 3450  6775c30a26b6f2028721b68a  QShQE5vmJ7c
# 3451  6775c30a26b6f2028721b68b  cJKQUHMHDn4
# 3452  6775c30a26b6f2028721b68c  -opyuUf4ha4
# 3453  6775c30a26b6f2028721b68d  EFzlL0Y7lYQ
#
#                                             description  \
# 0     ⚠️ ADVERTENCIA ⚠️ Este episodio es extremadame...
# 1     ¡HABLAMOS SIN CENSURA CON DOS AMIGAS INCREÍBLE...
# 2     ⚠️ ADVERTENCIA ⚠️ Este episodio es extremadame...
# 3     ¡SE PUSO RARA ESTA GRABACIÓN! \n\n😱 ¡AQUÍ ESTÁ...
# 4     Empezamos riendo y terminamos llorando... PERO...
# ...                                                 ...
# ...

# %%
# prompt: en una columna tengo en esquema de  temas que estan numerdos asi 1. 2. 3. 4. 5. quiero sacar cada uno indepnedinete de cada fila son 5

import pandas as pd

# Assuming your DataFrame is named 'df' and the column with numbered items is named 'Temas'
# Replace 'Temas' with the actual column name if it's different

def extract_topics(df):
    """
    Extracts individual topics from a column containing numbered items.

    Args:
        df: Pandas DataFrame with a 'Temas' column.

    Returns:
        A new DataFrame with each topic in a separate column.
    """
    # Handle missing values by creating an empty string for these columns
    df['temas'] = df['temas'].fillna('')

    # Extract topics and add them to new columns
    for i in range(1, 6):  # Assuming there are 5 topics
      df[f'tema_{i}'] = df['temas'].str.extract(f'{i}\\.\s*(.*?)(?=\s*{i+1}\\.|$)', expand=False).fillna('')

    return df


# Example usage assuming your DataFrame is named df
# Replace this with the actual column name if it's different from 'Temas'

#if 'Temas' in df.columns: #Check if the 'Temas' column exists
df = extract_topics(df)
df
#else:
#  print("Column 'Temas' not found in DataFrame.")
# Out:
#                            _id     video_id  \
# 0     6774708126b6f2028721a90e  jWhhuVzoMDw
# 1     6774708126b6f2028721a90f  mqLBdNUkt1U
# 2     6774708126b6f2028721a910  4BE0BwJdVUc
# 3     6774708126b6f2028721a911  Ev0e5Jh4JR4
# 4     6774708126b6f2028721a912  HRv7b8j88Ks
# ...                        ...          ...
# 3449  6775c30a26b6f2028721b689  84wDTy0JTk4
# 3450  6775c30a26b6f2028721b68a  QShQE5vmJ7c
# 3451  6775c30a26b6f2028721b68b  cJKQUHMHDn4
# 3452  6775c30a26b6f2028721b68c  -opyuUf4ha4
# 3453  6775c30a26b6f2028721b68d  EFzlL0Y7lYQ
#
#                                             description  \
# 0     ⚠️ ADVERTENCIA ⚠️ Este episodio es extremadame...
# 1     ¡HABLAMOS SIN CENSURA CON DOS AMIGAS INCREÍBLE...
# 2     ⚠️ ADVERTENCIA ⚠️ Este episodio es extremadame...
# 3     ¡SE PUSO RARA ESTA GRABACIÓN! \n\n😱 ¡AQUÍ ESTÁ...
# 4     Empezamos riendo y terminamos llorando... PERO...
# ...                                                 ...
# ...

# %%
# prompt: quiero preprocesar la data de manera que cada palabra sea trabajada individualmente y eliminando conecotres solo dejando lo de valor para despues  generar un grafico de esos que se muestran las palabras y que son mas grandes cuando aparecen mas

import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

# ... (your existing code for importing data from MongoDB) ...

def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    # Remove stop words (you might need to customize this list)
    stop_words = ['el', 'la', 'los', 'las', 'un', 'una', 'unos', 'unas', 'de', 'del', 'al', 'en', 'y', 'o', 'a', 'se', 'es', 'que', 'con', 'por', 'para', 'sin', 'sobre', 'entre', 'durante', 'desde', 'hasta', 'contra', 'según', 'como', 'pero', 'aunque', 'si', 'no', 'ni', 'o', 'u', 'mas', 'menos']
    words = [word for word in text.split() if word not in stop_words]

    return " ".join(words)


# Apply preprocessing to relevant columns (e.g., 'tema_1' to 'tema_5')

for i in range(1, 6):
    column_name = f'tema_{i}'
    if column_name in df.columns:
        df[column_name] = df[column_name].astype(str).apply(preprocess_text)  # Convert to string before preprocessing
    else:
        print(f"Warning: Column '{column_name}' not found in DataFrame.")

# Combine all preprocessed text data
all_text = " ".join(str(value) for i in range(1, 6) if f'tema_{i}' in df.columns for value in df[f'tema_{i}'].astype(str).values)

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the generated image:
plt.figure(figsize=(10, 5), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# prompt: ahora de cada columna creada de temas quiero generar un grafico de esos que se muestran las palabras y que son mas grandes cuando aparecen mas

import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd

# ... (your existing code to load the data into the DataFrame 'df') ...

def generate_wordclouds(df):
    """Generates word clouds for each topic column in the DataFrame."""

    for i in range(1, 6):  # Assuming up to 5 topics
        column_name = f'tema_{i}'
        if column_name in df.columns:
            text = ' '.join(df[column_name].astype(str))  # Convert to string and concatenate
            if text.strip():  # Check if the text is not empty
              wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
              plt.figure(figsize=(10, 5))
              plt.imshow(wordcloud, interpolation='bilinear')
              plt.axis("off")
              plt.title(f'Word Cloud for Tema {i}')
              plt.show()
            else:
              print(f"No data for Tema {i}. Skipping wordcloud generation.")
        else:
            print(f"Column '{column_name}' not found in DataFrame.")


# Example usage
generate_wordclouds(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# prompt: ahora de la variable viralidad sacar el numero que se tiene de cada fila pero este numero esta inmerso en el texto, el numero es un entero

import re

def extract_number_from_viralidad(text):
    """
    Extracts an integer number from a string.

    Args:
        text: The input string.

    Returns:
        The extracted integer, or None if no integer is found.
    """
    match = re.search(r'\d+', text)  # Use regex to find the first sequence of digits
    if match:
        return int(match.group(0))
    else:
        return None

# Example usage (assuming your DataFrame is named 'df' and the column is 'viralidad'):
if 'viralidad' in df.columns:
    df['viralidad_number'] = df['viralidad'].apply(extract_number_from_viralidad)
    print(df[['viralidad', 'viralidad_number']])  # Display both the original and extracted columns
else:
    print("Column 'viralidad' not found in the DataFrame.")
# Out:
#                                               viralidad  viralidad_number
# 0     Evaluando la descripción proporcionada, le oto...               7.0
# 1     Puntaje: 6\n\nEvaluación: La descripción tiene...               6.0
# 2     Puntaje: 7\n\nEvaluación: La descripción tiene...               7.0
# 3     Puntaje: 5\n\nEvaluación: La descripción tiene...               5.0
# 4     Le doy un puntaje de **7**. \n\nLa descripción...               7.0
# ...                                                 ...               ...
# 3449  Le doy un puntaje de 8. \n\nLa descripción tie...               8.0
# 3450  Le doy un puntaje de **8**. \n\nLa descripción...               8.0
# 3451  Puntaje: 8/10\n\nEvaluación:\n\n1. **Temática*...               8.0
# 3452  Le daría un puntaje de **8**. \n\nLa descripci...               8.0
# 3453  Puntaje: 8/10\n\nEvaluación:\n\n1. **Temas rel...               8.0
#
# [3454 rows x 2 columns]

# %%
df
# Out:
#                            _id     video_id  \
# 0     6774708126b6f2028721a90e  jWhhuVzoMDw
# 1     6774708126b6f2028721a90f  mqLBdNUkt1U
# 2     6774708126b6f2028721a910  4BE0BwJdVUc
# 3     6774708126b6f2028721a911  Ev0e5Jh4JR4
# 4     6774708126b6f2028721a912  HRv7b8j88Ks
# ...                        ...          ...
# 3449  6775c30a26b6f2028721b689  84wDTy0JTk4
# 3450  6775c30a26b6f2028721b68a  QShQE5vmJ7c
# 3451  6775c30a26b6f2028721b68b  cJKQUHMHDn4
# 3452  6775c30a26b6f2028721b68c  -opyuUf4ha4
# 3453  6775c30a26b6f2028721b68d  EFzlL0Y7lYQ
#
#                                             description  \
# 0     ⚠️ ADVERTENCIA ⚠️ Este episodio es extremadame...
# 1     ¡HABLAMOS SIN CENSURA CON DOS AMIGAS INCREÍBLE...
# 2     ⚠️ ADVERTENCIA ⚠️ Este episodio es extremadame...
# 3     ¡SE PUSO RARA ESTA GRABACIÓN! \n\n😱 ¡AQUÍ ESTÁ...
# 4     Empezamos riendo y terminamos llorando... PERO...
# ...                                                 ...
# ...

# %%
# prompt: ahora para la columna viralidad_number hacer un diagrama de barras graficando el valor abajo y la cantidad de videos que cumple eso con seaborn para un grafico mas bonito

import seaborn as sns
import matplotlib.pyplot as plt

# ... (your existing code) ...

# Assuming 'viralidad_number' column exists in your DataFrame 'df'
if 'viralidad_number' in df.columns:
    # Create the bar plot using seaborn
    plt.figure(figsize=(12, 6))  # Adjust figure size as needed
    sns.countplot(x='viralidad_number', data=df)
    plt.xlabel('Viralidad Number')
    plt.ylabel('Number of Videos')
    plt.title('Distribution of Viralidad Numbers')
    plt.xticks(rotation=0, ha='right')  # Rotate x-axis labels for better readability
    plt.tight_layout()  # Adjust layout to prevent labels from overlapping
    plt.show()
else:
    print("Column 'viralidad_number' not found in the DataFrame.")

# %%
# prompt: quiero unificar los valores de la variable sentimiento  algunos tienen punto otros estan en minuscula y mayuscula  y algunos en vez de neutro es neutral

# ... (your existing code) ...

def normalize_sentimiento(sentimiento):
    """Normalizes the 'sentimiento' values to lowercase and consistent naming."""
    if pd.isna(sentimiento):  # Handle missing values
        return None

    sentimiento = str(sentimiento).lower()  # Convert to lowercase
    sentimiento = sentimiento.replace("neutro", "neutral") # Replacing neutro with neutral
    sentimiento = sentimiento.replace(".", "") # Remove dots
    return sentimiento


# Apply the normalization function
if 'sentimiento' in df.columns:
    df['sentimiento'] = df['sentimiento'].apply(normalize_sentimiento)
else:
    print("Column 'sentimiento' not found in DataFrame.")


# ... (rest of your code) ...

# %%
# prompt: quiero generar un diagrama de pie para la variable sentimiemto pero el label no me aparece

# ... (your existing code) ...

# Assuming 'sentimiento' column exists in your DataFrame 'df'
if 'sentimiento' in df.columns:
    # Create the pie chart using matplotlib
    sentiment_counts = df['sentimiento'].value_counts()
    plt.figure(figsize=(8, 8))  # Adjust figure size as needed
    plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Distribution of Sentiments')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()
else:
    print("Column 'sentimiento' not found in the DataFrame.")

# ... (rest of your code) ...

# %%
# prompt: tengo una variable que se llama rangos de edad que estas asi numero-numero y quiero graficarla en un diagrama de barras , las que nos son de ese estilo numero-numero, dejalas como no se puede determinar  pero que aparezca en la grafica asi

# ... (your existing code) ...

import matplotlib.pyplot as plt

def plot_age_ranges(df):
    """Plots age ranges as a bar chart, handling invalid formats."""

    def categorize_age(age_range):
        if pd.isna(age_range):
          return "No se puede determinar"
        if re.match(r'\d+-\d+', str(age_range)):
            return age_range
        else:
            return "No se puede determinar"

    if 'rango_edad' in df.columns:
        df['categorized_age'] = df['rango_edad'].apply(categorize_age)
        age_counts = df['categorized_age'].value_counts()

        plt.figure(figsize=(12, 6))
        age_counts.plot(kind='bar')
        plt.xlabel('Rangos de Edad')
        plt.ylabel('Frecuencia')
        plt.title('Distribución de Rangos de Edad')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()
    else:
        print("Column 'rangos de edad' not found in the DataFrame.")

# Example usage
plot_age_ranges(df)

# ... (rest of your code) ...
